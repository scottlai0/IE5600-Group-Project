# %%
# !pip install yfinance
# !pip install pandas
# !pip install RISE
# Out:
# Requirement already satisfied: yfinance in d:\program files\anaconda\lib\site-packages (0.1.54)
# Requirement already satisfied: pandas>=0.24 in d:\program files\anaconda\lib\site-packages (from yfinance) (1.1.1)
# Requirement already satisfied: multitasking>=0.0.7 in d:\program files\anaconda\lib\site-packages (from yfinance) (0.0.9)
# Requirement already satisfied: numpy>=1.15 in d:\program files\anaconda\lib\site-packages (from yfinance) (1.19.1)
# Requirement already satisfied: requests>=2.20 in d:\program files\anaconda\lib\site-packages (from yfinance) (2.24.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\program files\anaconda\lib\site-packages (from pandas>=0.24->yfinance) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in d:\program files\anaconda\lib\site-packages (from pandas>=0.24->yfinance) (2020.1)
# Requirement already satisfied: certifi>=2017.4.17 in d:\program files\anaconda\lib\site-packages (from requests>=2.20->yfinance) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in d:\program files\anaconda\lib\site-packages (from requests>=2.20->yfinance) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\program files\anaconda\lib\site-packages (from requests>=2.20->yfinance) (1.25.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\program files\anaconda\lib\site-packages (from requests>=2.20->yfinance) (3.0.4)
# Requirement already satisfied: six>=1.5 in d:\program files\anaconda\lib\site-packages (from python-dateutil>=2.7.3->pandas>=0.24->yfinance) (1.15.0)
# Requirement already satisfied: pandas in d:\program files\anaconda\lib\site-packages (1.1.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in d:\program files\anaconda\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in d:\program files\anaconda\lib\site-packages (from pandas) (2020.1)
# Requirement already satisfied: numpy>=1.15.4 in d:\program files\anaconda\lib\site-packages (from pandas) (1.19.1)
# Requirement already satisfied: six>=1.5 in d:\program files\anaconda\lib\site-packages (from python-dateutil>=2.7.3->pandas) (1.15.0)
# Requirement already satisfied: RISE in d:\program files\anaconda\lib\site-packages (5.6.1)
# Requirement already satisfied: notebook>=5.5.0 in d:\program files\anaconda\lib\site-packages (from RISE) (6.1.1)
# Requirement already satisfied: tornado>=5.0 in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (6.0.4)
# Requirement already satisfied: jupyter-core>=4.6.1 in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (4.6.3)
# Requirement already satisfied: jinja2 in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (2.11.2)
# Requirement already satisfied: ipykernel in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (5.3.4)
# Requirement already satisfied: nbconvert in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (5.6.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (6.1.6)
# Requirement already satisfied: pyzmq>=17 in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (19.0.1)
# Requirement already satisfied: Send2Trash in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (1.5.0)
# Requirement already satisfied: ipython-genutils in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (0.2.0)
# Requirement already satisfied: terminado>=0.8.3 in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (0.8.3)
# Requirement already satisfied: traitlets>=4.2.1 in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (4.3.3)
# Requirement already satisfied: prometheus-client in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (0.8.0)
# Requirement already satisfied: nbformat in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (5.0.7)
# Requirement already satisfied: argon2-cffi in d:\program files\anaconda\lib\site-packages (from notebook>=5.5.0->RISE) (20.1.0)
# Requirement already satisfied: pywin32>=1.0; sys_platform == "win32" in d:\program files\anaconda\lib\site-packages (from jupyter-core>=4.6.1->notebook>=5.5.0->RISE) (227)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\program files\anaconda\lib\site-packages (from jinja2->notebook>=5.5.0->RISE) (1.1.1)
# Requirement already satisfied: ipython>=5.0.0 in d:\program files\anaconda\lib\site-packages (from ipykernel->notebook>=5.5.0->RISE) (7.18.1)
# Requirement already satisfied: mistune<2,>=0.8.1 in d:\program files\anaconda\lib\site-packages (from nbconvert->notebook>=5.5.0->RISE) (0.8.4)
# Requirement already satisfied: defusedxml in d:\program files\anaconda\lib\site-packages (from nbconvert->notebook>=5.5.0->RISE) (0.6.0)
# Requirement already satisfied: testpath in d:\program files\anaconda\lib\site-packages (from nbconvert->notebook>=5.5.0->RISE) (0.4.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in d:\program files\anaconda\lib\site-packages (from nbconvert->notebook>=5.5.0->RISE) (1.4.2)
# Requirement already satisfied: bleach in d:\program files\anaconda\lib\site-packages (from nbconvert->notebook>=5.5.0->RISE) (3.2.0)
# Requirement already satisfied: pygments in d:\program files\anaconda\lib\site-packages (from nbconvert->notebook>=5.5.0->RISE) (2.7.0)
# Requirement already satisfied: entrypoints>=0.2.2 in d:\program files\anaconda\lib\site-packages (from nbconvert->notebook>=5.5.0->RISE) (0.3)
# Requirement already satisfied: python-dateutil>=2.1 in d:\program files\anaconda\lib\site-packages (from jupyter-client>=5.3.4->notebook>=5.5.0->RISE) (2.8.1)
# Requirement already satisfied: six in d:\program files\anaconda\lib\site-packages (from traitlets>=4.2.1->notebook>=5.5.0->RISE) (1.15.0)
# Requirement already satisfied: decorator in d:\program files\anaconda\lib\site-packages (from traitlets>=4.2.1->notebook>=5.5.0->RISE) (4.4.2)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in d:\program files\anaconda\lib\site-packages (from nbformat->notebook>=5.5.0->RISE) (3.2.0)
# Requirement already satisfied: cffi>=1.0.0 in d:\program files\anaconda\lib\site-packages (from argon2-cffi->notebook>=5.5.0->RISE) (1.14.2)
# Requirement already satisfied: colorama; sys_platform == "win32" in d:\program files\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.5.0->RISE) (0.4.3)
# Requirement already satisfied: pickleshare in d:\program files\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.5.0->RISE) (0.7.5)
# Requirement already satisfied: backcall in d:\program files\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.5.0->RISE) (0.2.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in d:\program files\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.5.0->RISE) (3.0.7)
# Requirement already satisfied: jedi>=0.10 in d:\program files\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.5.0->RISE) (0.17.1)
# Requirement already satisfied: setuptools>=18.5 in d:\program files\anaconda\lib\site-packages (from ipython>=5.0.0->ipykernel->notebook>=5.5.0->RISE) (49.6.0.post20200814)
# Requirement already satisfied: packaging in d:\program files\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=5.5.0->RISE) (20.4)
# Requirement already satisfied: webencodings in d:\program files\anaconda\lib\site-packages (from bleach->nbconvert->notebook>=5.5.0->RISE) (0.5.1)
# Requirement already satisfied: attrs>=17.4.0 in d:\program files\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.5.0->RISE) (20.1.0)
# Requirement already satisfied: pyrsistent>=0.14.0 in d:\program files\anaconda\lib\site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook>=5.5.0->RISE) (0.17.3)
# Requirement already satisfied: pycparser in d:\program files\anaconda\lib\site-packages (from cffi>=1.0.0->argon2-cffi->notebook>=5.5.0->RISE) (2.20)
# Requirement already satisfied: wcwidth in d:\program files\anaconda\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=5.0.0->ipykernel->notebook>=5.5.0->RISE) (0.2.5)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in d:\program files\anaconda\lib\site-packages (from jedi>=0.10->ipython>=5.0.0->ipykernel->notebook>=5.5.0->RISE) (0.7.0)
# Requirement already satisfied: pyparsing>=2.0.2 in d:\program files\anaconda\lib\site-packages (from packaging->bleach->nbconvert->notebook>=5.5.0->RISE) (2.4.7)

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from IPython.display import HTML

# %% [markdown]
# 1) FAANG stocks and pharma companies, between 2019 and 2020 (see if pharma stocks is coming up)
# use price, volume, PE ratio, revenue?
# <br>2) Top 5 pharma companies in NYSE:
# JNJ, Norvatis, Pfizer, Merck, Abbott
#
# Analysis: Comparing different sectors before and after COVID19
# - Price - Yangjiao
# - Volume - Scott
# - PE Ratio - Shi Hang
# - Revenue - Jeffery
# - Full time employees - Yangjiao
# - Debt - Yongjie

# %% [markdown]
# __Presentation format__
# - Background (Jiao Yang)
# <ul>
# <li> Merck starts recruitment for COVID-19 Vaccine Human trial
# </ul>
# - Profile of Company (Jiao Yang)
# <ul>
# <li> Service Type, Employee count
# </ul>
# - Current Ratio (Yongjie)
# - PE Ratio (Shi Hang)
# - Price (Jiao Yang)
# - Volume (Scott)
# - Return % (Jeffrey)
# - Correlations of Returns

# %%
start = datetime(2019, 1, 1)
end = datetime(2020, 9, 6)

# %%
df_norvatis = yf.download('NVS', start=start, end=end, progress=False)
df_abbott = yf.download('ABT', start=start, end=end, progress=False)
df_pfizer = yf.download('PFE', start=start, end=end, progress=False)
df_merck = yf.download('MRK', start=start, end=end, progress=False)
df_jnj = yf.download('JNJ', start=start, end=end, progress=False)

df_facebook = yf.download('FB', start=start, end=end, progress=False)
df_amzn = yf.download('AMZN', start=start, end=end, progress=False)
df_apple = yf.download('AAPL', start=start, end=end, progress=False)
df_netflix = yf.download('NFLX', start=start, end=end, progress=False)
df_google = yf.download('GOOG', start=start, end=end, progress=False)

# %% [markdown]
# # Group C
# ## A0166840B LAI JUN GUO, SCOTT
# ## A0119529X JIAO YANG
# ## A0045148H KWOK JEFFERY
# ## A0214108U WANG YONGJIE
# ## A0099330A SHI HANG

# %% [markdown]
# # Background

# %% [markdown]
# ## 1.   Time Period 2019 Jan 1 to 2020 Sep 4
# ## 2.   How Covid-19 impact on different companies

# %% [markdown]
# # Profile of Companies
# ## Top 5 Technology Companies and Top 5 Healthcare companies
#
#
# <li> Facebook,Amazon,Google,Apple,Netflix
#
# <li> Norvatis,Abbott,Pfizer,Merck,Johnson & Johnson

# %%
# skip
m1 = yf.Ticker("FB")
m2=yf.Ticker("AMZN")
m3=yf.Ticker("GOOG")
m4=yf.Ticker("AAPL")
m5=yf.Ticker("NFLX")
m6=yf.Ticker("NVS")
m7=yf.Ticker("ABT")
m8=yf.Ticker("PFE")
m9=yf.Ticker("MRK")
m10=yf.Ticker("JNJ")
print('FB'+':'+m1.info['sector'] +','+ str(m1.info['fullTimeEmployees']))
print('AMZN'+':'+m2.info['sector']+','+str(m2.info['fullTimeEmployees']))
print('GOOG'+':'+m3.info['sector']+','+ str(m3.info['fullTimeEmployees']))
print('AAPL'+':'+m4.info['sector']+','+str(m4.info['fullTimeEmployees']))
print('NFLX'+':'+m5.info['sector']+','+str(m5.info['fullTimeEmployees']))
print('NVS'+':'+m6.info['sector']+','+ str(m6.info['fullTimeEmployees']))
print('ABT'+':'+m7.info['sector']+','+ str(m7.info['fullTimeEmployees']))
print('PFE'+':'+m8.info['sector']+','+ str(m8.info['fullTimeEmployees']))
print(m9)
print('JNJ'+':'+m10.info['sector'] +',' +str(m10.info['fullTimeEmployees']))



HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# FB:Communication Services,52534
# AMZN:Consumer Cyclical,798000
# GOOG:Communication Services,127498
# AAPL:Technology,137000
# NFLX:Communication Services,8600
# NVS:Healthcare,110000
# ABT:Healthcare,107000
# PFE:Healthcare,88300
# yfinance.Ticker object <MRK>
# JNJ:Healthcare,132200
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# subslide
labels = ['Communication Services', 'Consumer Cyclical', 'Healthcare', 'Technology']
sizes = [3, 1, 5, 1]
colors = ['yellowgreen', 'gold', 'lightskyblue', 'lightcoral']
patches, texts = plt.pie(sizes, colors=colors, shadow=True, startangle=90)
plt.legend(patches, labels, loc="best")
plt.axis('equal')
plt.tight_layout()
plt.show()


fig = plt.figure()
ax = fig.add_axes([0,0,1,1])
coms = ['FB', 'AMZN', 'GOOG', 'AAPL', 'NFLX','NVS','ABT','PFE','MRK','JNJ']
rpes = [75160000//52534, 321780000//798000, 166030000//127498, 273860000//137000, 22630000//8600, 49530000//110000, 287750/107000, 49200000//88300, 47190000//69000, 80500000//132200]
plt.ylabel('Revenue Per Employee')
plt.title('Revenue Per Employee by different company')
ax.bar(coms,rpes)
plt.show()

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Current Ratio

# %%
# !pip install requests
# !pip install panda
# Out:
# Requirement already satisfied: requests in d:\program files\anaconda\lib\site-packages (2.24.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\program files\anaconda\lib\site-packages (from requests) (1.25.10)
# Requirement already satisfied: idna<3,>=2.5 in d:\program files\anaconda\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\program files\anaconda\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in d:\program files\anaconda\lib\site-packages (from requests) (2020.6.20)
# Requirement already satisfied: panda in d:\program files\anaconda\lib\site-packages (0.3.1)
# Requirement already satisfied: requests in d:\program files\anaconda\lib\site-packages (from panda) (2.24.0)
# Requirement already satisfied: setuptools in d:\program files\anaconda\lib\site-packages (from panda) (49.6.0.post20200814)
# Requirement already satisfied: idna<3,>=2.5 in d:\program files\anaconda\lib\site-packages (from requests->panda) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in d:\program files\anaconda\lib\site-packages (from requests->panda) (1.25.10)
# Requirement already satisfied: certifi>=2017.4.17 in d:\program files\anaconda\lib\site-packages (from requests->panda) (2020.6.20)
# Requirement already satisfied: chardet<4,>=3.0.2 in d:\program files\anaconda\lib\site-packages (from requests->panda) (3.0.4)

# %%
import requests
import matplotlib.pyplot as plt
import seaborn as sns
apple_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/AAPL?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
apple_fr=apple_fr.json()
y=[]
x=[]
for i in range(len(apple_fr)):
    y.append(apple_fr[i]['currentRatio'])
    x.append(apple_fr[i]['date'])
figsize=8,5
figure, ax = plt.subplots(figsize=figsize)
for i in ax.get_xticklabels():
    i.set_visible(False)
for i in ax.get_xticklabels()[::20]:
    i.set_visible(True)
ax.set_title("apple")
plt.plot(x[::-1],y[::-1],'y',label='A',linewidth=2.0,ms=10)

amazon_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/AMZN?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
amazon_fr=amazon_fr.json()
y=[]
x=[]
for i in range(len(amazon_fr)):
    y.append(amazon_fr[i]['currentRatio'])
    x.append(amazon_fr[i]['date'])
figsize=8,5
figure, ax = plt.subplots(figsize=figsize)
for i in ax.get_xticklabels():
    i.set_visible(False)
for i in ax.get_xticklabels()[::20]:
    i.set_visible(True)
ax.set_title("amazon")
plt.plot(x[::-1],y[::-1],'y',label='A',linewidth=2.0,ms=10)

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Price to Earnings (PE) Ratio

# %%
# skip for this part

import pandas as pd 
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
#
# ## Valuation of company change before and after COVID breakout

# %%
# skip

start = datetime(2019,12,30)
end = datetime(2020,9,6)

company_price = [0]*10
company_close = [0]*10
eps = [0]*10
names = ['Facebook','Amazon', 'Google','Apple','Netflix','Norvatis','Abbott','Pfizer','Merck','Johnson & Johnson']
abre = ['FB','AMZN','GOOG','AAPL','NFLX','NVS','ABT','PFE','MRK','JNJ']
color = ['teal','dodgerblue','skyblue','darkturquoise','royalblue','lightcoral', 'firebrick', 'orangered','tomato', 'red']

# %%
#skip

for i in range(10):
    company_price[i] = yf.download(abre[i], start=start, end = end, progress = False)
    company_close[i] = company_price[i]['Adj Close']
    if i == 8:
        eps[8] = 4.1
    else:
        eps[i] = yf.Ticker(abre[i]).info.get("trailingEps")

# %%
# Sub-slides

plt.figure(figsize=(15,8))

for i in range(10):
    plt.plot(company_close[i]/eps[i], color[i], label = names[i])
    
plt.xlabel('Date')
plt.ylabel('PE ratio growth')
plt.legend()
plt.show()

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Stock Price Trend

# %%
# skip
facebook = yf.download('FB', start=start, end=end, progress=False)
amazon = yf.download('AMZN', start=start, end=end, progress=False)
alphabet = yf.download('GOOG', start=start, end=end, progress=False)
apple=yf.download('AAPL',start=start,end=end,progress=False)
netflix=yf.download('NFLX',start=start, end=end, progress=False)
norvatis = yf.download('NVS', start=start, end=end, progress=False)
abbott = yf.download('ABT', start=start, end=end, progress=False)
pfizer = yf.download('PFE', start=start, end=end, progress=False)
merck = yf.download('MRK', start=start, end=end, progress=False)
jnj = yf.download('JNJ', start=start, end=end, progress=False)
facebook_close = facebook['Adj Close']
amazon_close = amazon['Adj Close']
alphabet_close = alphabet['Adj Close']
apple_close=apple['Adj Close']
netflix_close=netflix['Adj Close']
norvatis_close=norvatis['Adj Close']
abbott_close=abbott['Adj Close']
pfizer_close=pfizer['Adj Close']
merck_close=merck['Adj Close']
jnj_close=jnj['Adj Close']

# %%
# skip
fig, ax1 = plt.subplots(figsize=(30,20))
fig2,ax6 = plt.subplots(figsize=(30,15))
ax1.plot(facebook_close, 'teal', lw=4, label='Facebook')
ax1.set_yscale("log")
ax1.tick_params(labelsize=20)
ax1.set_xlabel('Time',fontsize=20)
ax1.set_ylabel('Stock Price in USD',fontsize=20 )
ax1.plot(amazon_close, 'dodgerblue', lw=4, label='Amazon')
ax1.plot(alphabet_close, 'skyblue', lw=4, label='Alphabet')
ax1.plot(apple_close,'darkturquoise',lw=4,label='Apple')
ax1.plot(netflix_close,'royalblue',lw=4,label='Netflix')

ax6.plot(norvatis_close,'lightcoral',lw=4,label='Norvatis')
ax6.set_xlabel('Time',fontsize=20)
ax6.set_ylabel('Stock Price in USD',fontsize=20)
ax6.set_yscale("log")
ax6.tick_params(labelsize=20)
ax6.plot(abbott_close,'firebrick',lw=4,label='Abbott')
ax6.plot(pfizer_close,'orangered',lw=4,label='Pfizer')
ax6.plot(merck_close,'tomato',lw=4,label='Merck')
ax6.plot(jnj_close,'red',lw=4,label='Johnson&Johnson')

line_labels1 = ['Facebook','Amazon','Alphabet','Apple','Netflix']
legend1=fig.legend(#[ax1, ax2, ax3,ax4,ax5],        # The line objects
           labels = line_labels1,   # The labels for each line
           fontsize=20,
           loc="upper left",  # Position of legend
           borderaxespad=1,      # Small spacing around legend box          
           )
legend1.set_title('Top 5 Tech Companies',prop={'size':20})

line_labels2=['Norvatis','Abbott','Pfizer','Merck','Johnson&Johnson']
legend2=fig2.legend(#[ax6,ax7,ax8,ax9,ax10],
          labels=line_labels2,
          loc="upper left",
          fontsize=20,
          borderaxespad=1,
          )
legend2.set_title('Top 5 Pharmaceutical Companies',prop={'size':20})
plt.show()


HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
# subslide
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Volume

# %%
import numpy as np

start = datetime(2019, 1, 1)
end = datetime(2020, 9, 6)

tech_color = ['teal','dodgerblue','skyblue','darkturquoise','royalblue']
tech_names = ['Facebook','Amazon','Apple','Netflix','Google']

pharm_color = ['lightcoral','firebrick','orangered','tomato','red']
pharm_names = ['Norvatis','Abbott','Pfizer','Merck','Johnson & Johnson']

# %%
tech = yf.download(['FB','AMZN','AAPL','NFLX','GOOG'], start=start, end=end, progress=False)
tech_vol = tech['Volume']
tech_vol_change = 100*tech['Volume'].pct_change().dropna()

# %%
fig, ax1 = plt.subplots(figsize=(25,20), nrows=5,ncols=2)
i = 0
for vol in tech_vol:
      ax1[i,0].plot((tech_vol[vol]), color[i], lw=1)
      ax1[i,0].set_title(names[i])
      ax1[i,0].set_ylabel('Volume')
      i+=1

plt.figure(figsize=(30,10))
for i in range(tech_vol_change.shape[1]):
  ax1[i,1].plot(tech_vol_change.iloc[:,i], lw = 1, color = tech_color[i])
  ax1[i,1].set_title(tech_names[i])
  ax1[i,1].axhline(y=0, color='black', linestyle='--', lw ='1')
  ax1[i,1].set_ylabel('% Change in Volume')

  
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
pharm = yf.download(['NVS','ABT','PFE','MRK','JNJ'],start=start, end=end, progress=False)
pharm_vol = pharm['Volume']
pharm_vol_change = 100*pharm['Volume'].pct_change().dropna()

fig, ax2 = plt.subplots(figsize=(25,20), nrows=5,ncols=2)
i = 0
for vol in pharm_vol:
      ax2[i,0].plot(pharm_vol[vol], color[i], lw=1)
      ax2[i,0].set_title(pharm_names[i])
      ax2[i,0].set_ylabel('Volume')
      i+=1

plt.figure(figsize=(30,10))
for i in range(pharm_vol_change.shape[1]):
  ax2[i,1].plot(pharm_vol_change.iloc[:,i], lw = 1, color = color[i])
  ax2[i,1].set_title(pharm_names[i])
  ax2[i,1].axhline(y=0, color='black', linestyle='--', lw ='1')
  ax2[i,1].set_ylabel('% Change in Volume')

  
HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Stock Returns
#
#
# *   **Evaluating on the daily returns**
#
# <br>1.Using of log returns
# <br>2.Plotting of daily returns
#
# ![Capture.PNG](data:image/png;base64,...)
#
# *   **Computing the log returns for the following:**
#
# <br> 1.   Individual Stock (Apple, JNJ)
# <br> 2.   Group of Stocks (5 FAANG Stocks, 5 Top Medical Companies)
#
# Libraries Used: numpy, matplotlib

# %%
#NOT for SLIDE

#start end
start = datetime(2019, 1, 1)
end = datetime(2020, 9, 6)
 
 #for the returns graphs
  
df = yf.download(['^GSPC', 'AAPL', 'FB','AMZN','GOOG','NFLX','NVS','ABT','PFE','MRK','JNJ'], 
                 start=start, 
                 end=end,
                 progress=False)

df = df[['Adj Close']]
df.columns = df.columns.droplevel(0)

df['aapl_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))
df['jnj_rtn'] = np.log(df.JNJ / df.JNJ.shift(1))
df['medical_rtn'] = np.log(df.NVS / df.NVS.shift(1))*0.2 + np.log(df.ABT / df.ABT.shift(1))*0.2 + np.log(df.PFE / df.PFE.shift(1))*0.2 + np.log(df.MRK / df.MRK.shift(1))*0.2 + np.log(df.JNJ / df.JNJ.shift(1))*0.2
df['tech_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))*0.2 + np.log(df.FB / df.FB.shift(1))*0.2 + np.log(df.AMZN / df.AMZN.shift(1))*0.2 + np.log(df.GOOG / df.GOOG.shift(1))*0.2 + np.log(df.NFLX / df.NFLX.shift(1))*0.2
df['all_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))*0.1 + np.log(df.FB / df.FB.shift(1))*0.1 + np.log(df.AMZN / df.AMZN.shift(1))*0.1 + np.log(df.GOOG / df.GOOG.shift(1))*0.1 + np.log(df.NFLX / df.NFLX.shift(1))*0.1 + np.log(df.NVS / df.NVS.shift(1))*0.1 + np.log(df.ABT / df.ABT.shift(1))*0.1 + np.log(df.PFE / df.PFE.shift(1))*0.1 + np.log(df.MRK / df.MRK.shift(1))*0.1 + np.log(df.JNJ / df.JNJ.shift(1))*0.1


fig, ax = plt.subplots(1, 1, figsize=(24, 5))

df.aapl_rtn.plot(color = 'darkturquoise')
ax.set(xlabel = 'Date', 
          ylabel = 'Log returns (%)', 
          title = 'AAPL Returns time series')

fig, ax = plt.subplots(1, 1, figsize=(24, 5))
df.jnj_rtn.plot(color = 'red')
ax.set(xlabel = 'Date', 
          ylabel = 'Log returns (%)', 
          title = 'JNJ Returns time series')


HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %%
#FOR SLIDE: JEFFERY
#Graphs on Returns
plt.figure(figsize=(24,8))

df.medical_rtn.plot(color = 'green')
df.tech_rtn.plot(color = 'purple')
df.all_rtn.plot(color = 'black')

plt.xlabel('Date')
plt.ylabel('Log Returns %')
plt.title('Returns time series')
plt.legend(['5 Medical Stocks', 'FAANG Stocks' ,'All 10 Stocks'])


HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>

# %% [markdown]
# # Correlation of Stocks vs the Index
#
# *   **Correlation between returns of Stock vs Index)**
#
# <br>1.   Individual Stock (Apple, JNJ)
# <br>2.   Group of Stocks (5 FAANG Stocks, 5 Top Medical Companies, All 10 Stocks)
#
# *   **Diversification of your Porfolio**
#
# <br>1.   Invest in Single Stock or in Group of Stocks?
# <br>2.   Stock Picking: How returns compare Medical Stocks vs Tech Stocks from Jan 2019 to Sep 2020?
#
#
# <br> Libraries Used: seaborn, numpy, matplotlib

# %%
#NOT FOR SLIDE

#start of the correlation graph
df = yf.download(['^GSPC', 'AAPL', 'FB','AMZN','GOOG','NFLX','NVS','ABT','PFE','MRK','JNJ'], 
                 start=start, 
                 end=end,
                 progress=False)

df = df[['Adj Close']]
df.columns = df.columns.droplevel(0)
df = df.rename(columns={'^GSPC': 'sp500'})

#5 FAANG stock example
#'AAPL', 'FB','AMZN','GOOG','NFLX'

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))*0.2 + np.log(df.FB / df.FB.shift(1))*0.2 + np.log(df.AMZN / df.AMZN.shift(1))*0.2 + np.log(df.GOOG / df.GOOG.shift(1))*0.2 + np.log(df.NFLX / df.NFLX.shift(1))*0.2
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

fig, ax = plt.subplots(1, 2, figsize=(20, 8))

ax[0] = sns.regplot(ax = ax[0], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'purple'})
ax[0].set(title=f'S&P 500 vs. FANNG Stocks ($\\rho$ = {corr_coeff:.2f})',
       ylabel='FANNG log returns',
       xlabel='S&P 500 log returns')

#NVS','ABT','PFE','MRK','JNJ' 

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.NVS / df.NVS.shift(1))*0.2 + np.log(df.ABT / df.ABT.shift(1))*0.2 + np.log(df.PFE / df.PFE.shift(1))*0.2 + np.log(df.MRK / df.MRK.shift(1))*0.2 + np.log(df.JNJ / df.JNJ.shift(1))*0.2
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

ax[1] = sns.regplot(ax = ax[1], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'green'}, scatter_kws={"color": "orange"})
ax[1].set(title=f'S&P 500 vs. 5 Pharma Stocks ($\\rho$ = {corr_coeff:.2f})',
       ylabel='5 Pharma log returns',
       xlabel='S&P 500 log returns')
# Out:
# [Text(0.5, 1.0, 'S&P 500 vs. 5 Pharma Stocks ($\\rho$ = 0.83)'),
#  Text(0, 0.5, '5 Pharma log returns'),
#  Text(0.5, 0, 'S&P 500 log returns')]

# %%
#FOR SLIDE
#Apple stock example

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

fig, ax = plt.subplots(1, 2, figsize=(20, 8))

ax[0] = sns.regplot(ax = ax[0], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'darkturquoise'})
ax[0].set(title=f'S&P 500 vs. Apple ($\\rho$ = {corr_coeff:.2f})',ylabel='Apple log returns',xlabel='S&P 500 log returns')

#JNJ stock example

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.JNJ / df.JNJ.shift(1))
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

ax[1] = sns.regplot(ax = ax[1], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'red'})
ax[1].set(title=f'S&P 500 vs. JNJ ($\\rho$ = {corr_coeff:.2f})',ylabel='JNJ log returns',xlabel='S&P 500 log returns')


#Combined Example from the 2nd row graphs

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))*0.2 + np.log(df.FB / df.FB.shift(1))*0.2 + np.log(df.AMZN / df.AMZN.shift(1))*0.2 + np.log(df.GOOG / df.GOOG.shift(1))*0.2 + np.log(df.NFLX / df.NFLX.shift(1))*0.2
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

fig, ax = plt.subplots(1, 2, figsize=(20, 8))

ax[0] = sns.regplot(ax = ax[0], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'purple'})

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.NVS / df.NVS.shift(1))*0.2 + np.log(df.ABT / df.ABT.shift(1))*0.2 + np.log(df.PFE / df.PFE.shift(1))*0.2 + np.log(df.MRK / df.MRK.shift(1))*0.2 + np.log(df.JNJ / df.JNJ.shift(1))*0.2
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

ax[0] = sns.regplot(ax = ax[0], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'green'}, scatter_kws={"color": "orange"})
ax[0].set(title=f'S&P 500 vs. Tech Stocks (Blue / Purple), Medical Stocks (Orange / Green) ',ylabel='Stock log returns',xlabel='S&P 500 log returns')

#All stocks combined

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))*0.1 + np.log(df.FB / df.FB.shift(1))*0.1 + np.log(df.AMZN / df.AMZN.shift(1))*0.1 + np.log(df.GOOG / df.GOOG.shift(1))*0.1 + np.log(df.NFLX / df.NFLX.shift(1))*0.1 + np.log(df.NVS / df.NVS.shift(1))*0.1 + np.log(df.ABT / df.ABT.shift(1))*0.1 + np.log(df.PFE / df.PFE.shift(1))*0.1 + np.log(df.MRK / df.MRK.shift(1))*0.1 + np.log(df.JNJ / df.JNJ.shift(1))*0.1
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

ax[1] = sns.regplot(ax = ax[1], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'black'}, scatter_kws={"color": "red"})
ax[1].set(title=f'S&P 500 vs. All 10 Stocks ($\\rho$ = {corr_coeff:.2f})',ylabel='All 10 Stocks log returns', xlabel='S&P 500 log returns')


HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# [Text(0, 0.5, 'All 10 Stocks log returns'),
#  Text(0.5, 0, 'S&P 500 log returns'),
#  Text(0.5, 1.0, 'S&P 500 vs. All 10 Stocks ($\\rho$ = 0.91)')]

# %% [markdown]
# # Thank you
