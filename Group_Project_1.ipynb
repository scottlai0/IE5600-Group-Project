# %% [markdown]
# <a href="https://colab.research.google.com/github/scottlai0/IE5600-Group-Project/blob/master/Group_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# !pip install pandas
# !pip install RISE

# %%
import pandas as pd
import yfinance as yf
from datetime import datetime
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# 1) FAANG stocks and pharma companies, between 2019 and 2020 (see if pharma stocks is coming up)
# use price, volume, PE ratio, revenue?
# <br>2) Top 5 pharma companies in NYSE:
# JNJ, Norvatis, Pfizer, Merck, Abbott
#
# Analysis: Comparing different sectors before and after COVID19
# - Price - Yangjiao
# - Volume - Scott
# - PE Ratio - Shi Hang
# - Revenue - Jeffery
# - Full time employees - Yangjiao
# - Debt - Yongjie

# %% [markdown]
# __Presentation format__
# - Background (Yang Jiao)
# <ul>
# <li> Merck starts recruitment for COVID-19 Vaccine Human trial
# </ul>
# - Profile of Company (Yang Jiao)
# <ul>
# <li> Service Type, Employee count
# </ul>
# - Current Ratio (Yongjie)
# - PE Ratio (Shi Hang)
# - Price (Yang Jiao)
# - Volume (Scott)
# - Return % (Jeffrey)
# - Correlations of Returns

# %%
start = datetime(2019, 1, 1)
end = datetime(2020, 9, 6)

# %%
  df_norvatis = yf.download('NVS', start=start, end=end, progress=False)
df_abbott = yf.download('ABT', start=start, end=end, progress=False)
df_pfizer = yf.download('PFE', start=start, end=end, progress=False)
df_merck = yf.download('MRK', start=start, end=end, progress=False)
df_jnj = yf.download('JNJ', start=start, end=end, progress=False)

df_facebook = yf.download('FB', start=start, end=end, progress=False)
df_amzn = yf.download('AMZN', start=start, end=end, progress=False)
df_apple = yf.download('AAPL', start=start, end=end, progress=False)
df_netflix = yf.download('NFLX', start=start, end=end, progress=False)
df_google = yf.download('GOOG', start=start, end=end, progress=False)

# %%
m = yf.Ticker("NVS")
m.major_holders

# %%
m._institutional_holders

# %% [markdown]
# # Background

# %% [markdown]
# # Profile of Companies

# %% [markdown]
# # Current Ratio
# Yongjie

# %%
# !pip install requests
# !pip install panda
import requests
import matplotlib.pyplot as plt
import seaborn as sns
facebook_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/FB?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
apple_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/AAPL?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
amazon_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/AMZN?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
alphabet_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/GOOG?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
netflix_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/NFLX?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
norvatis_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/NVS?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
abbott_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/ABT?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
pfizer_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/PFE?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
merck_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/MRK?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
jnj_fr=requests.get('https://financialmodelingprep.com/api/v3/ratios/JNJ?apikey=ff76fe869a5bf1f03c6f38a0c366980e')
facebook_fr=facebook_fr.json()
apple_fr=apple_fr.json()
amazon_fr=amazon_fr.json()
alphabet_fr=alphabet_fr.json()
netflix_fr=netflix_fr.json()
norvatis_fr=norvatis_fr.json()
abbott_fr=abbott_fr.json()
pfizer_fr=pfizer_fr.json()
merck_fr=merck_fr.json()
jnj_fr=jnj_fr.json()
s1=[]

s2=[]
s3=[]
s4=[]
s5=[]
s6=[]
s7=[]
s8=[]
s9=[]
s0=[]
d0=[]
for i in range(len(facebook_fr)):
    s0.append(facebook_fr[i]['currentRatio'])
    d0.append(facebook_fr[i]['date'])
for i in range(len(apple_fr)):
    s1.append(apple_fr[i]['currentRatio'])
for i in range(len(amazon_fr)):
    s2.append(amazon_fr[i]['currentRatio'])
for i in range(len(alphabet_fr)):
    s3.append(alphabet_fr[i]['currentRatio'])
for i in range(len(netflix_fr)):
    s4.append(netflix_fr[i]['currentRatio'])
for i in range(len(norvatis_fr)):
    s5.append(norvatis_fr[i]['currentRatio'])
for i in range(len(abbott_fr)):
    s6.append(abbott_fr[i]['currentRatio'])
for i in range(len(pfizer_fr)):
    s7.append(pfizer_fr[i]['currentRatio'])
for i in range(len(merck_fr)):
    s8.append(merck_fr[i]['currentRatio'])
for i in range(len(jnj_fr)):
    s9.append(jnj_fr[i]['currentRatio'])
ax1.plot(d0[::-1],s0[::-1], 'b', lw=4, label='Facebook')
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests) (2020.6.20)
# Collecting panda
#   Downloading https://files.pythonhosted.org/packages/79/03/74996420528fe488ce17c42b6400531c8067d7eb661c304fa3aa8fdad17c/panda-0.3.1.tar.gz
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from panda) (49.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from panda) (2.23.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->panda) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->panda) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->panda) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->panda) (2020.6.20)
# Building wheels for collected packages: panda
#   Building wheel for panda (setup.py) ... done
#   Created wheel for panda: filename=panda-0.3.1-cp36-none-any.whl size=7260 sha256=9067cac1327192b67474698d01ec9353ae462ddd5b38c6fb0f239e5195c07fd3
#   Stored in directory: /root/.cache/pip/wheels/c6/c8/45/06ed898b0bb401c1ff207dbb05b1587ff28860a236d98b1996
# Successfully built panda
# Installing collected packages: panda
# Successfully installed panda-0.3.1
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-e98d66e5b541> in <module>()
#      57 for i in range(len(jnj_fr)):
#      58     s9.append(jnj_fr[i]['currentRatio'])
# ---> 59 ax1.plot(d0[::-1],s0[::-1], 'b', lw=4, label='Facebook')
#      60
#
# AttributeError: 'numpy.ndarray' object has no attribute 'plot'

# %% [markdown]
# # Price to Earnings (PE) Ratio
# Shi Hang

# %%
import pandas as pd 
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
start = datetime(2019,12,30)
end = datetime(2020,9,6)
# set lists
price = [0]*10
eps = [0]*10
company = [0]*10
abre = ['FB','AMZN','GOOG','AAPL','NFLX','NVS','ABT','PFE','MRK','JNJ']
# get prices
facebook = yf.download('FB', start=start, progress = False)
amazon = yf.download('AMZN', start=start, end=end,progress=False)
google = yf.download('GOOG', start=start, end=end,progress=False)
apple = yf.download('AAPL',start=start,end=end,progress=False)
netflix = yf.download('NFLX',start=start, end=end,progress=False)
norvatis = yf.download('NVS', start=start, end=end,progress=False)
abbott = yf.download('ABT', start=start, end=end,progress=False)
pfizer = yf.download('PFE', start=start, end=end,progress=False)
merck = yf.download('MRK', start=start, end=end,progress=False)
jnj = yf.download('JNJ', start=start, end=end,progress=False)
# get close price
facebook_close = facebook['Adj Close']
amazon_close = amazon['Adj Close']
google_close = google['Adj Close']
apple_close = apple['Adj Close']
netflix_close = netflix['Adj Close']
norvatis_close = norvatis['Adj Close']
abbott_close = abbott['Adj Close']
pfizer_close = pfizer['Adj Close']
merck_close = merck['Adj Close']
jnj_close = jnj['Adj Close']
#get eps
facebook_eps = yf.Ticker('FB').info.get("trailingEps")
amazon_eps = yf.Ticker('AMZN').info.get("trailingEps")
google_eps = yf.Ticker('GOOG').info.get("trailingEps")
apple_eps = yf.Ticker('AAPL').info.get("trailingEps")
netflix_eps = yf.Ticker('NFLX').info.get("trailingEps")
norvatis_eps = yf.Ticker('NVS').info.get("trailingEps")
abbott_eps = yf.Ticker('ABT').info.get("trailingEps")
pfizer_eps = yf.Ticker('PFE').info.get("trailingEps")
merck_eps = 4.10 #yf.Ticker('MRK').info.get("trailingEps")
jnj_eps = yf.Ticker('JNJ').info.get("trailingEps")

#plot graphs
plt.figure(figsize=(15,8))
plt.plot(facebook_close/facebook_eps/25, 'teal',label = 'Facebook')
plt.plot(amazon_close/amazon_eps/71, 'dodgerblue', label = 'Amazon')
plt.plot(google_close/google_eps/29.5, 'skyblue', label ='Google')
plt.plot(apple_close/apple_eps/22, 'darkturquoise', label ='Apple')
plt.plot(netflix_close/netflix_eps/55, 'royalblue', label ='Netflix')

plt.plot(norvatis_close/norvatis_eps/29, 'lightcoral',label = 'Norvatis')
plt.plot(abbott_close/abbott_eps/49, 'firebrick', label = 'Abbott')
plt.plot(pfizer_close/pfizer_eps/15, 'orangered', label ='Pfizer')
plt.plot(merck_close/merck_eps/4.1, 'tomato', label ='Merck')
plt.plot(jnj_close/jnj_eps/25, 'red', label ='JNJ')


plt.xlabel('Date')
plt.ylabel('PE ratio')
plt.legend()




plt.show()

# %% [markdown]
# # Price
# Yang Jiao

# %%
facebook = yf.download('FB', start=start, end=end, progress=False)
amazon = yf.download('AMZN', start=start, end=end, progress=False)
alphabet = yf.download('GOOG', start=start, end=end, progress=False)
apple=yf.download('AAPL',start=start,end=end,progress=False)
netflix=yf.download('NFLX',start=start, end=end, progress=False)
norvatis = yf.download('NVS', start=start, end=end, progress=False)
abbott = yf.download('ABT', start=start, end=end, progress=False)
pfizer = yf.download('PFE', start=start, end=end, progress=False)
merck = yf.download('MRK', start=start, end=end, progress=False)
jnj = yf.download('JNJ', start=start, end=end, progress=False)
facebook_close = facebook['Adj Close']
amazon_close = amazon['Adj Close']
alphabet_close = alphabet['Adj Close']
apple_close=apple['Adj Close']
netflix_close=netflix['Adj Close']
norvatis_close=norvatis['Adj Close']
abbott_close=abbott['Adj Close']
pfizer_close=pfizer['Adj Close']
merck_close=merck['Adj Close']
jnj_close=jnj['Adj Close']

fig, ax1 = plt.subplots(figsize=(30,20))
# ax2 = ax1.plot()  # Same x axis
# ax3 = ax1.plot() 
# ax4 = ax1.plot() 
# ax5 = ax1.plot() 
fig2,ax6 = plt.subplots(figsize=(30,15))
# ax7 = ax6.twinx()
# ax8 = ax6.twinx()
# ax9 = ax6.twinx()
# ax10=ax6.twinx()

# ax1.plot(facebook_close, 'b', lw=4, label='Facebook')
# ax1.set_xlabel('Time',fontsize=20)
# ax1.set_ylabel('Stock Price in USD',fontsize=20)
# ax2.plot(amazon_close, 'r', lw=4, label='Amazon')
# ax3.plot(alphabet_close, 'g', lw=4, label='Alphabet')
# ax4.plot(apple_close,'c',lw=4,label='Apple')
# ax5.plot(netflix_close,'y',lw=4,label='Netflix')

ax1.plot(facebook_close, 'teal', lw=4, label='Facebook')
ax1.set_yscale("log")
ax1.tick_params(labelsize=20)
ax1.set_xlabel('Time',fontsize=20)
ax1.set_ylabel('Stock Price in USD',fontsize=20 )

ax1.plot(amazon_close, 'dodgerblue', lw=4, label='Amazon')
ax1.plot(alphabet_close, 'skyblue', lw=4, label='Alphabet')
ax1.plot(apple_close,'darkturquoise',lw=4,label='Apple')
ax1.plot(netflix_close,'royalblue',lw=4,label='Netflix')

ax6.plot(norvatis_close,'lightcoral',lw=4,label='Norvatis')
ax6.set_xlabel('Time',fontsize=20)
ax6.set_ylabel('Stock Price in USD',fontsize=20)
ax6.set_yscale("log")
ax6.tick_params(labelsize=20)
ax6.plot(abbott_close,'firebrick',lw=4,label='Abbott')
ax6.plot(pfizer_close,'orangered',lw=4,label='Pfizer')
ax6.plot(merck_close,'tomato',lw=4,label='Merck')
ax6.plot(jnj_close,'red',lw=4,label='Johnson&Johnson')


line_labels1 = ['Facebook','Amazon','Alphabet','Apple','Netflix']

legend1=fig.legend(#[ax1, ax2, ax3,ax4,ax5],        # The line objects
           labels = line_labels1,   # The labels for each line
           fontsize=20,
           loc="upper left",  # Position of legend
           borderaxespad=1,      # Small spacing around legend box          
           )
legend1.set_title('Top 5 Tech Companies',prop={'size':20})

line_labels2=['Norvatis','Abbott','Pfizer','Merck','Johnson&Johnson']

legend2=fig2.legend(#[ax6,ax7,ax8,ax9,ax10],
          labels=line_labels2,
          loc="upper left",
          fontsize=20,
          borderaxespad=1,
          )
legend2.set_title('Top 5 Pharmaceutical Companies',prop={'size':20})
plt.show()
m1 = yf.Ticker("FB")
m2=yf.Ticker("AMZN")
m3=yf.Ticker("GOOG")
m4=yf.Ticker("AAPL")
m5=yf.Ticker("NFLX")
m6=yf.Ticker("NVS")
m7=yf.Ticker("ABT")
m8=yf.Ticker("PFE")
m9=yf.Ticker("MRK")
m10=yf.Ticker("JNJ")
print(m1.info)
print(m2.info)
print(m3.info)
print(m4.info)
print(m5.info)
print(m6.info)
print(m7.info)
print(m8.info)
print(m9)
print(m10.info)
# Out:
# {'zip': '94025', 'sector': 'Communication Services', 'fullTimeEmployees': 52534, 'longBusinessSummary': "Facebook, Inc. develops products that enable people to connect and share with friends and family through mobile devices, personal computers, virtual reality headsets, and in-home devices worldwide. The company's products include Facebook that enables people to connect, share, discover, and communicate with each other on mobile devices and personal computers; Instagram, a community for sharing photos, videos, and private messages; Messenger, a messaging application for people to connect with friends, family, groups, and businesses across platforms and devices; and WhatsApp, a messaging application that is used by people and businesses to communicate in a private way. It also provides Oculus, a hardware, software, and developer ecosystem, which allows people to come together and connect with each other through its Oculus virtual reality products. Facebook, Inc. was founded in 2004 and is headquartered in Menlo Park, California.", 'city': 'Menlo Park', 'phone': '650-543-4800', 'state': 'CA', 'country': 'United States', 'companyOfficers': [], 'website': 'http://investor.fb.com', 'maxAge': 1, 'address1': '1601 Willow Road', 'industry': 'Internet Content & Information', 'previousClose': 268.09, 'regularMarketOpen': 270.06, 'twoHundredDayAverage': 219.53029, 'trailingAnnualDividendYield': None, 'payoutRatio': 0, 'volume24Hr': None, 'regularMarketDayHigh': 271.39, 'navPrice': None, 'averageDailyVolume10Day': 25496114, 'totalAssets': None, 'regularMarketPreviousClose': 268.09, 'fiftyDayAverage': 266.04742, 'trailingAnnualDividendRate': None, 'open': 270.06, 'toCurrency': None, 'averageVolume10days': 25496114, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': None, 'beta': 1.255852, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 262.64, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 32.600876, 'regularMarketVolume': 18913883, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 759523835904, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 25891615, 'priceToSalesTrailing12Months': 10.10583, 'dayLow': 262.64, 'ask': 266.45, 'ytdReturn': None, 'askSize': 900, 'volume': 18913883, 'fiftyTwoWeekHigh': 304.67, 'forwardPE': 26.34486, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 137.1, 'bid': 265.8, 'tradeable': False, 'dividendYield': None, 'bidSize': 800, 'dayHigh': 271.39, 'exchange': 'NMS', 'shortName': 'Facebook, Inc.', 'longName': 'Facebook, Inc.', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'FB', 'messageBoardId': 'finmb_20765463', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 9.477, 'beta3Year': None, 'profitMargins': 0.31296, 'enterpriseToEbitda': 20.898, '52WeekChange': 0.43169355, 'morningStarRiskRating': None, 'forwardEps': 10.12, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 2404280064, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'bookValue': 38.753, 'sharesShort': 25240206, 'sharesPercentSharesOut': 0.0089, 'fundFamily': None, 'lastFiscalYearEnd': 1577750400, 'heldPercentInstitutions': 0.79412, 'netIncomeToCommon': 23520999424, 'trailingEps': 8.178, 'lastDividendValue': None, 'SandP52WeekChange': 0.11441445, 'priceToBook': 6.8797255, 'heldPercentInsiders': 0.00664, 'nextFiscalYearEnd': 1640908800, 'mostRecentQuarter': 1593475200, 'shortRatio': 0.89, 'sharesShortPreviousMonthDate': 1596153600, 'floatShares': 2392236107, 'enterpriseValue': 712286797824, 'threeYearAverageReturn': None, 'lastSplitDate': None, 'lastSplitFactor': None, 'legalType': None, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': 0.979, 'dateShortInterest': 1598832000, 'pegRatio': 2.04, 'lastCapGain': None, 'shortPercentOfFloat':  ...
# {'zip': '98109-5210', 'sector': 'Consumer Cyclical', 'fullTimeEmployees': 798000, 'longBusinessSummary': 'Amazon.com, Inc. engages in the retail sale of consumer products and subscriptions in North America and internationally. The company operates through three segments: North America, International, and Amazon Web Services (AWS). It sells merchandise and content purchased for resale from third-party sellers through physical and online stores. The company also manufactures and sells electronic devices, including Kindle, Fire tablets, Fire TVs, Rings, and Echo and other devices; provides Kindle Direct Publishing, an online service that allows independent authors and publishers to make their books available in the Kindle Store; and develops and produces media content. In addition, it offers programs that enable sellers to sell their products on its Websites, as well as its stores; and programs that allow authors, musicians, filmmakers, skill and app developers, and others to publish and sell content. Further, the company provides compute, storage, database, and other AWS services, as well as fulfillment, advertising, publishing, and digital content subscriptions. Additionally, it offers Amazon Prime, a membership program, which provides free shipping of various items; access to streaming of movies and TV episodes; and other services. The company also operates in the food delivery business in Bengaluru, India. It serves consumers, sellers, developers, enterprises, and content creators. The company also has utility-scale solar projects in China, Australia, and the United States. Amazon.com, Inc. was founded in 1994 and is headquartered in Seattle, Washington.', 'city': 'Seattle', 'phone': '206-266-1000', 'state': 'WA', 'country': 'United States', 'companyOfficers': [], 'website': 'http://www.amazon.com', 'maxAge': 1, 'address1': '410 Terry Avenue North', 'industry': 'Internet Retail', 'previousClose': 3175.11, 'regularMarketOpen': 3208.69, 'twoHundredDayAverage': 2592.27, 'trailingAnnualDividendYield': None, 'payoutRatio': 0, 'volume24Hr': None, 'regularMarketDayHigh': 3217.3408, 'navPrice': None, 'averageDailyVolume10Day': 6082242, 'totalAssets': None, 'regularMarketPreviousClose': 3175.11, 'fiftyDayAverage': 3227.196, 'trailingAnnualDividendRate': None, 'open': 3208.69, 'toCurrency': None, 'averageVolume10days': 6082242, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': None, 'beta': 1.323857, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 3083.98, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 119.68429, 'regularMarketVolume': 4991892, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 1560883363840, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 4853475, 'priceToSalesTrailing12Months': 4.850748, 'dayLow': 3083.98, 'ask': 3110, 'ytdReturn': None, 'askSize': 1400, 'volume': 4991892, 'fiftyTwoWeekHigh': 3552.25, 'forwardPE': 70.566574, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 1626.03, 'bid': 3107.11, 'tradeable': False, 'dividendYield': None, 'bidSize': 1000, 'dayHigh': 3217.3408, 'exchange': 'NMS', 'shortName': 'Amazon.com, Inc.', 'longName': 'Amazon.com, Inc.', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'AMZN', 'messageBoardId': 'finmb_18749', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 4.913, 'beta3Year': None, 'profitMargins': 0.040960003, 'enterpriseToEbitda': 39.947, '52WeekChange': 0.72372556, 'morningStarRiskRating': None, 'forwardEps': 44.16, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 500889984, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'bookValue': 147.162, 'sharesShort': 2035049, 'sharesPercentSharesOut': 0.0041, 'fundFamily': None, 'lastFiscalYearEnd': 1577750400, 'heldPercentInstitu ...
# {'zip': '94043', 'sector': 'Communication Services', 'fullTimeEmployees': 127498, 'longBusinessSummary': 'Alphabet Inc. provides online advertising services in the United States, Europe, the Middle East, Africa, the Asia-Pacific, Canada, and Latin America. It offers performance and brand advertising services. The company operates through Google and Other Bets segments. The Google segment offers products, such as Ads, Android, Chrome, Google Cloud, Google Maps, Google Play, Hardware, Search, and YouTube, as well as technical infrastructure. It also offers digital content, cloud services, hardware devices, and other miscellaneous products and services. The Other Bets segment includes businesses, including Access, Calico, CapitalG, GV, Verily, Waymo, and X, as well as Internet and television services. Alphabet Inc. was founded in 1998 and is headquartered in Mountain View, California.', 'city': 'Mountain View', 'phone': '650-253-0000', 'state': 'CA', 'country': 'United States', 'companyOfficers': [], 'website': 'http://www.abc.xyz', 'maxAge': 1, 'address1': '1600 Amphitheatre Parkway', 'industry': 'Internet Content & Information', 'previousClose': 1532.02, 'regularMarketOpen': 1536, 'twoHundredDayAverage': 1393.81, 'trailingAnnualDividendYield': None, 'payoutRatio': 0, 'volume24Hr': None, 'regularMarketDayHigh': 1575.2, 'navPrice': None, 'averageDailyVolume10Day': 2261157, 'totalAssets': None, 'regularMarketPreviousClose': 1532.02, 'fiftyDayAverage': 1551.6469, 'trailingAnnualDividendRate': None, 'open': 1536, 'toCurrency': None, 'averageVolume10days': 2261157, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': None, 'beta': 1.07525, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 1497.36, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 33.428295, 'regularMarketVolume': 1597087, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 1032284471296, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 1816559, 'priceToSalesTrailing12Months': 6.2174573, 'dayLow': 1497.36, 'ask': 1523.99, 'ytdReturn': None, 'askSize': 900, 'volume': 1597087, 'fiftyTwoWeekHigh': 1733.18, 'forwardPE': 26.948786, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 1013.536, 'bid': 1514.2, 'tradeable': False, 'dividendYield': None, 'bidSize': 1000, 'dayHigh': 1575.2, 'exchange': 'NMS', 'shortName': 'Alphabet Inc.', 'longName': 'Alphabet Inc.', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'GOOG', 'messageBoardId': 'finmb_29096', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 5.598, 'beta3Year': None, 'profitMargins': 0.18993, 'enterpriseToEbitda': 20.189, '52WeekChange': 0.23505235, 'morningStarRiskRating': None, 'forwardEps': 56.43, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 333631008, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'bookValue': 304.342, 'sharesShort': 2290314, 'sharesPercentSharesOut': 0.0034, 'fundFamily': None, 'lastFiscalYearEnd': 1577750400, 'heldPercentInstitutions': 0.7062, 'netIncomeToCommon': 31534000128, 'trailingEps': 45.492, 'lastDividendValue': None, 'SandP52WeekChange': 0.11441445, 'priceToBook': 4.996747, 'heldPercentInsiders': 0.05746, 'nextFiscalYearEnd': 1640908800, 'mostRecentQuarter': 1593475200, 'shortRatio': 0.99, 'sharesShortPreviousMonthDate': 1596153600, 'floatShares': 610521680, 'enterpriseValue': 929401470976, 'threeYearAverageReturn': None, 'lastSplitDate': 1430092800, 'lastSplitFactor': '10000000:10000000', 'legalType': None, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': -0.3, 'dateShortInterest': 1598832000, 'pegRatio': 5.69, 'lastCapGain': None, 'shortPercentOfFloat': None, 'sharesShortPriorMonth': 2472852, 'category': None, 'fiveYearAverageReturn': None, 'regularMarketPrice': 1536, 'logo_url ...
# {'zip': '95014', 'sector': 'Technology', 'fullTimeEmployees': 137000, 'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. It also sells various related services. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, HomePod, iPod touch, and other Apple-branded and third-party accessories. It also provides digital content stores and streaming services; AppleCare support services; and iCloud, a cloud service, which stores music, photos, contacts, calendars, mail, documents, and others. In addition, the company offers various service, such as Apple Arcade, a game subscription service; Apple Card, a co-branded credit card; Apple News+, a subscription news and magazine service; and Apple Pay, a cashless payment service, as well as licenses its intellectual property, and provides other related services. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It sells and delivers third-party applications for its products through the App Store, Mac App Store, and Watch App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. has a collaboration with Google to develop COVID-19 tracking system for Android and iOS devices. Apple Inc. was founded in 1977 and is headquartered in Cupertino, California.', 'city': 'Cupertino', 'phone': '408-996-1010', 'state': 'CA', 'country': 'United States', 'companyOfficers': [], 'website': 'http://www.apple.com', 'maxAge': 1, 'address1': 'One Apple Park Way', 'industry': 'Consumer Electronics', 'previousClose': 113.49, 'regularMarketOpen': 114.57, 'twoHundredDayAverage': 86.68598, 'trailingAnnualDividendYield': 0.0068904753, 'payoutRatio': 0.2373, 'volume24Hr': None, 'regularMarketDayHigh': 115.23, 'navPrice': None, 'averageDailyVolume10Day': 223056400, 'totalAssets': None, 'regularMarketPreviousClose': 113.49, 'fiftyDayAverage': 114.41464, 'trailingAnnualDividendRate': 0.782, 'open': 114.57, 'toCurrency': None, 'averageVolume10days': 223056400, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': 0.82, 'exDividendDate': 1596758400, 'beta': 1.284838, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 110.03, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 33.980583, 'regularMarketVolume': 180860325, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 1915479916544, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 170920981, 'priceToSalesTrailing12Months': 6.994453, 'dayLow': 110.03, 'ask': 112.02, 'ytdReturn': None, 'askSize': 800, 'volume': 180860325, 'fiftyTwoWeekHigh': 137.98, 'forwardPE': 28.940569, 'fromCurrency': None, 'fiveYearAvgDividendYield': 1.54, 'fiftyTwoWeekLow': 53.1525, 'bid': 111.96, 'tradeable': False, 'dividendYield': 0.0072000003, 'bidSize': 4000, 'dayHigh': 115.23, 'exchange': 'NMS', 'shortName': 'Apple Inc.', 'longName': 'Apple Inc.', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'AAPL', 'messageBoardId': 'finmb_24937', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 7.101, 'beta3Year': None, 'profitMargins': 0.21334, 'enterpriseToEbitda': 24.719, '52WeekChange': 1.0372896, 'morningStarRiskRating': None, 'forwardEps': 3.87, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 17102499840, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'bookValue': 4.218, 'sharesShort': 79684337, 'sharesPercentSharesOut': 0.0047, 'fundFamily': None, 'lastFiscalYearEnd': 1569628800, 'heldPer ...
# {'zip': '95032', 'sector': 'Communication Services', 'fullTimeEmployees': 8600, 'longBusinessSummary': 'Netflix, Inc. provides subscription streaming entertainment service. It offers TV series, documentaries, and feature films across various genres and languages. The company provides members the ability to receive streaming content through a host of Internet-connected screens, including TVs, digital video players, television set-top boxes, and mobile devices. It also provides DVDs-by-mail membership services. The company has approximately 167 million paid members in 190 countries. Netflix, Inc. was founded in 1997 and is headquartered in Los Gatos, California.', 'city': 'Los Gatos', 'phone': '408-540-3700', 'state': 'CA', 'country': 'United States', 'companyOfficers': [], 'website': 'http://www.netflix.com', 'maxAge': 1, 'address1': '100 Winchester Circle', 'industry': 'Entertainment', 'previousClose': 480.67, 'regularMarketOpen': 486.485, 'twoHundredDayAverage': 439.81464, 'trailingAnnualDividendYield': None, 'payoutRatio': 0, 'volume24Hr': None, 'regularMarketDayHigh': 493.73, 'navPrice': None, 'averageDailyVolume10Day': 6703114, 'totalAssets': None, 'regularMarketPreviousClose': 480.67, 'fiftyDayAverage': 500.12686, 'trailingAnnualDividendRate': None, 'open': 486.485, 'toCurrency': None, 'averageVolume10days': 6703114, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': None, 'exDividendDate': None, 'beta': 0.969899, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 476.81, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 81.39649, 'regularMarketVolume': 5035200, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 212582465536, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 7424893, 'priceToSalesTrailing12Months': 9.394533, 'dayLow': 476.81, 'ask': 481.5, 'ytdReturn': None, 'askSize': 1100, 'volume': 5035200, 'fiftyTwoWeekHigh': 575.37, 'forwardPE': 54.83845, 'fromCurrency': None, 'fiveYearAvgDividendYield': None, 'fiftyTwoWeekLow': 252.28, 'bid': 480, 'tradeable': False, 'dividendYield': None, 'bidSize': 1300, 'dayHigh': 493.73, 'exchange': 'NMS', 'shortName': 'Netflix, Inc.', 'longName': 'Netflix, Inc.', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'NFLX', 'messageBoardId': 'finmb_32012', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 9.861, 'beta3Year': None, 'profitMargins': 0.1185, 'enterpriseToEbitda': 57.738, '52WeekChange': 0.6379421, 'morningStarRiskRating': None, 'forwardEps': 8.79, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 441015008, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'bookValue': 21.166, 'sharesShort': 9878569, 'sharesPercentSharesOut': 0.0224, 'fundFamily': None, 'lastFiscalYearEnd': 1577750400, 'heldPercentInstitutions': 0.83487, 'netIncomeToCommon': 2681477120, 'trailingEps': 5.922, 'lastDividendValue': None, 'SandP52WeekChange': 0.11441445, 'priceToBook': 22.773788, 'heldPercentInsiders': 0.01622, 'nextFiscalYearEnd': 1640908800, 'mostRecentQuarter': 1593475200, 'shortRatio': 1.78, 'sharesShortPreviousMonthDate': 1596153600, 'floatShares': 434532516, 'enterpriseValue': 223137579008, 'threeYearAverageReturn': None, 'lastSplitDate': 1436918400, 'lastSplitFactor': '7:1', 'legalType': None, 'morningStarOverallRating': None, 'earningsQuarterlyGrowth': 1.661, 'dateShortInterest': 1598832000, 'pegRatio': 2.2, 'lastCapGain': None, 'shortPercentOfFloat': 0.0229, 'sharesShortPriorMonth': 10625583, 'category': None, 'fiveYearAverageReturn': None, 'regularMarketPrice': 486.485, 'logo_url': 'https://logo.clearbit.com/netflix.com'}
# {'zip': '4056', 'sector': 'Healthcare', 'fullTimeEmployees': 110000, 'longBusinessSummary': "Novartis AG researches, develops, manufactures, and markets healthcare products worldwide. Its Innovative Medicines segment offers prescription medicines for patients and healthcare providers. It also provides ophthalmology, neuroscience, immunology, hepatology and dermatology, respiratory, cardio-metabolic, established, and cardiovascular, renal and metabolism medicine products. The company's Sandoz segment provides active ingredients and finished dosage forms of small molecule pharmaceuticals to third parties across a range of therapeutic areas, as well as finished dosage form anti-infectives. It also provides active pharmaceutical ingredients and intermediates primarily antibiotics; protein- or other biotechnology-based products, including biosimilars; and biotechnology manufacturing services. Novartis AG has collaboration agreements with Pear Therapeutics; Wyss Institute for Biologically Inspired Engineering at Harvard University and the Dana-Farber Cancer Institute; Science 37; Bill & Melinda Gates Foundation; Amgen; University of California, Berkeley; Bristol-Myers Squibb; Drugs for Neglected Diseases initiative (DNDi); TScan Therapeutics; and Dyno Therapeutics Inc. The company was founded in 1895 and is headquartered in Basel, Switzerland.", 'city': 'Basel', 'phone': '41 61 324 1111', 'country': 'Switzerland', 'companyOfficers': [], 'website': 'http://www.novartis.com', 'maxAge': 1, 'address1': 'Lichtstrasse 35', 'fax': '41 61 324 7826', 'industry': 'Drug Manufacturers—General', 'previousClose': 88.52, 'regularMarketOpen': 90.42, 'twoHundredDayAverage': 85.170715, 'trailingAnnualDividendYield': 0.034342524, 'payoutRatio': 0.9832, 'volume24Hr': None, 'regularMarketDayHigh': 90.68, 'navPrice': None, 'averageDailyVolume10Day': 1645942, 'totalAssets': None, 'regularMarketPreviousClose': 88.52, 'fiftyDayAverage': 85.564, 'trailingAnnualDividendRate': 3.04, 'open': 90.42, 'toCurrency': None, 'averageVolume10days': 1645942, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': 3.09, 'exDividendDate': 1583193600, 'beta': 0.404216, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 89.34, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 28.651577, 'regularMarketVolume': 1858920, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 206524465152, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 1693898, 'priceToSalesTrailing12Months': 4.1698527, 'dayLow': 89.34, 'ask': 90.67, 'ytdReturn': None, 'askSize': 900, 'volume': 1858920, 'fiftyTwoWeekHigh': 99.84, 'forwardPE': 14.403846, 'fromCurrency': None, 'fiveYearAvgDividendYield': 3.39, 'fiftyTwoWeekLow': 69.18, 'bid': 88.46, 'tradeable': False, 'dividendYield': 0.0349, 'bidSize': 800, 'dayHigh': 90.68, 'exchange': 'NYQ', 'shortName': 'Novartis AG', 'longName': 'Novartis AG', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'NVS', 'messageBoardId': 'finmb_382553', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 4.733, 'beta3Year': None, 'profitMargins': 0.14557, 'enterpriseToEbitda': 12.951, '52WeekChange': 0.043417692, 'morningStarRiskRating': None, 'forwardEps': 6.24, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 2288979968, 'fundInceptionDate': None, 'annualReportExpenseRatio': None, 'bookValue': 23.509, 'sharesShort': 2077811, 'sharesPercentSharesOut': 0.00090000004, 'fundFamily': None, 'lastFiscalYearEnd': 1577750400, 'heldPercentInstitutions': 0.11057, 'netIncomeToCommon': 7209999872, 'trailingEps': 3.137, 'lastDividendValue': None, 'SandP52WeekChange': 0.11441445, 'priceToBook': 3.8232164, 'heldPercentInsiders': 1.0000001e-05, 'nextFiscalYearEnd': 1640908800, 'mostRecentQuarter': 1593475200, 'shortRatio': 1.3, 'sharesShortPreviousMonthDate': 1596153600, ...
# {'zip': '60064-6400', 'sector': 'Healthcare', 'fullTimeEmployees': 107000, 'longBusinessSummary': "Abbott Laboratories discovers, develops, manufactures, and sells health care products worldwide. Its Established Pharmaceutical Products segment offers generic pharmaceuticals for the treatment of pancreatic exocrine insufficiency; irritable bowel syndrome or biliary spasm; intrahepatic cholestasis or depressive symptom; gynecological disorder; hormone replacement therapy; dyslipidemia; hypertension; hypothyroidism; MÃ©niÃ¨re's disease and vestibular vertigo; pain, fever, and inflammation; migraine; and anti-infective clarithromycin, as well as provides influenza vaccines and products that regulate physiological rhythm of the colon. The company's Diagnostic Products segment offers laboratory systems in the areas of immunoassay, clinical chemistry, hematology, and transfusion; molecular diagnostics systems that automates the extraction, purification, and preparation of DNA and RNA from patient samples, as well as detects and measures infectious agents; cartridges for blood analysis; rapid diagnostics systems; molecular point-of-care testing for HIV, influenza A and B, RSV, and strep A; cardiometabolic test systems; drug and alcohol test systems, as well as remote patient monitoring and consumer self-test systems; and informatics and automation solutions for use in laboratories. Its Nutritional Products segment provides pediatric and adult nutritional products. The company's Medical Devices segment offers rhythm management, electrophysiology, heart failure, vascular, and structural heart devices for the treatment of cardiovascular diseases, as well as neuromodulation devices for the management of chronic pain and movement disorders. This segment also provides glucose and blood glucose monitoring systems. Abbott Laboratories has an agreement with Tandem Diabetes Care to develop and commercialize integrated diabetes solutions. The company was founded in 1888 and is headquartered in North Chicago, Illinois.", 'city': 'North Chicago', 'phone': '224 667 6100', 'state': 'IL', 'country': 'United States', 'companyOfficers': [], 'website': 'http://www.abbott.com', 'maxAge': 1, 'address1': '100 Abbott Park Road', 'industry': 'Medical Devices', 'address2': 'Abbott Park', 'previousClose': 104, 'regularMarketOpen': 105.28, 'twoHundredDayAverage': 91.57779, 'trailingAnnualDividendYield': 0.013461539, 'payoutRatio': 0.7907, 'volume24Hr': None, 'regularMarketDayHigh': 105.7, 'navPrice': None, 'averageDailyVolume10Day': 4990471, 'totalAssets': None, 'regularMarketPreviousClose': 104, 'fiftyDayAverage': 102.79629, 'trailingAnnualDividendRate': 1.4, 'open': 105.28, 'toCurrency': None, 'averageVolume10days': 4990471, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': 1.44, 'exDividendDate': 1594684800, 'beta': 0.952062, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 104.3248, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 60.485268, 'regularMarketVolume': 4025536, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 185374490624, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 5401984, 'priceToSalesTrailing12Months': 5.895385, 'dayLow': 104.3248, 'ask': 104.94, 'ytdReturn': None, 'askSize': 800, 'volume': 4025536, 'fiftyTwoWeekHigh': 114.2, 'forwardPE': 25.91584, 'fromCurrency': None, 'fiveYearAvgDividendYield': 1.92, 'fiftyTwoWeekLow': 61.61, 'bid': 104, 'tradeable': False, 'dividendYield': 0.0138, 'bidSize': 900, 'dayHigh': 105.7, 'exchange': 'NYQ', 'shortName': 'Abbott Laboratories', 'longName': 'Abbott Laboratories', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'ABT', 'messageBoardId': 'finmb_247483', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 6.368, 'beta3Year': None, 'profitMargins': 0.098900005, 'ent ...
# {'zip': '10017', 'sector': 'Healthcare', 'fullTimeEmployees': 88300, 'longBusinessSummary': 'Pfizer Inc. develops, manufactures, and sells healthcare products worldwide. It offers medicines and vaccines in various therapeutic areas, including internal medicine, such as cardiovascular metabolic and pain under the Eliquis, Chantix/Champix, and Premarin family brands; oncology, such as biologics, small molecules, immunotherapies, and biosimilars under the Ibrance, Sutent, Xtandi, Xalkori, Inlyta, Braftovi + Mektovi brands; and sterile injectable and anti-infective medicines under the Sulperazon, Medrol, Vfend, and Zithromax brands. The company also provides medicines and vaccines in various therapeutic areas, such as pneumococcal disease, meningococcal disease, and tick-borne encephalitis under the Prevnar 13/Prevenar 13 (pediatric/adult), FSME-IMMUN, Nimenrix, and Trumenba brands; biosimilars for chronic immune and inflammatory diseases under the Xeljanz, Enbrel, Inflectra, and Eucrisa brands; and amyloidosis, hemophilia, and endocrine diseases under the Vyndaqel/Vyndamax, BeneFIX, Genotropin, and Refacto AF/Xyntha brands. In addition, the company is involved in the contract manufacturing business. It serves wholesalers, retailers, hospitals, clinics, government agencies, pharmacies, and individual provider offices, as well as disease control and prevention centers. The company has collaboration and/or co-promotion agreements with Bristol-Myers Squibb Company and Astellas Pharma US, Inc.; licensing agreement with Akcea Therapeutics, Inc; strategic alliance with Verily Life Sciences LLC; collaboration agreements with Merck KGaA and Valneva SE; clinical trial collaboration and supply agreement with IDEAYA Biosciences, Inc.; material transfer and collaboration agreement with BioNTech SE to co-develop COVID-19 vaccine; clinical supply collaboration with Jiangsu Alphamab Biopharmaceuticals Co., Ltd; and research collaboration and license agreement with BioInvent International AB. Pfizer Inc. was founded in 1849 and is headquartered in New York, New York.', 'city': 'New York', 'phone': '212 733 2323', 'state': 'NY', 'country': 'United States', 'companyOfficers': [], 'website': 'http://www.pfizer.com', 'maxAge': 1, 'address1': '235 East 42nd Street', 'industry': 'Drug Manufacturers—General', 'previousClose': 35.65, 'regularMarketOpen': 35.74, 'twoHundredDayAverage': 35.66307, 'trailingAnnualDividendYield': 0.041514724, 'payoutRatio': 0.585, 'volume24Hr': None, 'regularMarketDayHigh': 36.11, 'navPrice': None, 'averageDailyVolume10Day': 26004628, 'totalAssets': None, 'regularMarketPreviousClose': 35.65, 'fiftyDayAverage': 37.87, 'trailingAnnualDividendRate': 1.48, 'open': 35.74, 'toCurrency': None, 'averageVolume10days': 26004628, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': 1.52, 'exDividendDate': 1596067200, 'beta': 0.658862, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 35.45, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 14.279493, 'regularMarketVolume': 22813794, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 204841877504, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 29158367, 'priceToSalesTrailing12Months': 4.163707, 'dayLow': 35.45, 'ask': 36.48, 'ytdReturn': None, 'askSize': 2200, 'volume': 22813794, 'fiftyTwoWeekHigh': 40.97, 'forwardPE': 10.799401, 'fromCurrency': None, 'fiveYearAvgDividendYield': 3.59, 'fiftyTwoWeekLow': 27.88, 'bid': 36.35, 'tradeable': False, 'dividendYield': 0.042600002, 'bidSize': 1400, 'dayHigh': 36.11, 'exchange': 'NYQ', 'shortName': 'Pfizer, Inc.', 'longName': 'Pfizer Inc.', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'PFE', 'messageBoardId': 'finmb_162270', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 5.142, 'beta3Year': None, 'profitMargins' ...
# yfinance.Ticker object <MRK>
# {'zip': '08933', 'sector': 'Healthcare', 'fullTimeEmployees': 132200, 'longBusinessSummary': "Johnson & Johnson researches and develops, manufactures, and sells various products in the health care field worldwide. It operates in three segments: Consumer, Pharmaceutical, and Medical Devices. The Consumer segment offers baby care products under the JOHNSON'S brand; oral care products under the LISTERINE brand; beauty products under the AVEENO, CLEAN & CLEAR, DR. CI:LABO NEUTROGENA, and OGX brands; over-the-counter medicines, including acetaminophen products under the TYLENOL brand; cold, flu, and allergy products under the SUDAFED brand; allergy products under the BENADRYL and ZYRTEC brands; ibuprofen products under the MOTRIN IB brand; and acid reflux products under the PEPCID brand. This segment also provides women's health products, such as sanitary pads and tampons under the STAYFREE, CAREFREE, and o.b. brands; wound care products comprising adhesive bandages under the BAND-AID brand; and first aid products under the NEOSPORIN brand. The Pharmaceutical segment offers products in various therapeutic areas, including immunology, infectious diseases, neuroscience, oncology, pulmonary hypertension, and cardiovascular and metabolic diseases. The Medical Devices segment provides orthopedic products; general surgery, biosurgical, endomechanical, and energy products; electrophysiology products to treat cardiovascular diseases; and vision care products, such as disposable contact lenses and ophthalmic products related to cataract and laser refractive surgery. The company markets its products to general public, and retail outlets and distributors, as well as distributes directly to wholesalers, hospitals, and health care professionals for prescription use. Johnson & Johnson was founded in 1886 and is based in New Brunswick, New Jersey.", 'city': 'New Brunswick', 'phone': '732 524 0400', 'state': 'NJ', 'country': 'United States', 'companyOfficers': [], 'website': 'http://www.jnj.com', 'maxAge': 1, 'address1': 'One Johnson & Johnson Plaza', 'industry': 'Drug Manufacturers—General', 'previousClose': 146.91, 'regularMarketOpen': 147.05, 'twoHundredDayAverage': 144.18307, 'trailingAnnualDividendYield': 0.026274588, 'payoutRatio': 0.6784, 'volume24Hr': None, 'regularMarketDayHigh': 148.53, 'navPrice': None, 'averageDailyVolume10Day': 6942500, 'totalAssets': None, 'regularMarketPreviousClose': 146.91, 'fiftyDayAverage': 149.332, 'trailingAnnualDividendRate': 3.86, 'open': 147.05, 'toCurrency': None, 'averageVolume10days': 6942500, 'expireDate': None, 'yield': None, 'algorithm': None, 'dividendRate': 4.04, 'exDividendDate': 1598227200, 'beta': 0.681716, 'circulatingSupply': None, 'startDate': None, 'regularMarketDayLow': 146.63, 'priceHint': 2, 'currency': 'USD', 'trailingPE': 25.999296, 'regularMarketVolume': 3917326, 'lastMarket': None, 'maxSupply': None, 'openInterest': None, 'marketCap': 389078122496, 'volumeAllCurrencies': None, 'strikePrice': None, 'averageVolume': 6289401, 'priceToSalesTrailing12Months': 4.833089, 'dayLow': 146.63, 'ask': 147.78, 'ytdReturn': None, 'askSize': 1000, 'volume': 3917326, 'fiftyTwoWeekHigh': 157, 'forwardPE': 16.347345, 'fromCurrency': None, 'fiveYearAvgDividendYield': 2.65, 'fiftyTwoWeekLow': 109.16, 'bid': 147.55, 'tradeable': False, 'dividendYield': 0.0275, 'bidSize': 1100, 'dayHigh': 148.53, 'exchange': 'NYQ', 'shortName': 'Johnson & Johnson', 'longName': 'Johnson & Johnson', 'exchangeTimezoneName': 'America/New_York', 'exchangeTimezoneShortName': 'EDT', 'isEsgPopulated': False, 'gmtOffSetMilliseconds': '-14400000', 'quoteType': 'EQUITY', 'symbol': 'JNJ', 'messageBoardId': 'finmb_139677', 'market': 'us_market', 'annualHoldingsTurnover': None, 'enterpriseToRevenue': 4.945, 'beta3Year': None, 'profitMargins': 0.18863001, 'enterpriseToEbitda': 14.629, '52WeekChange': 0.14080596, 'morningStarRiskRating': None, 'forwardEps': 9.04, 'revenueQuarterlyGrowth': None, 'sharesOutstanding': 2632819968, 'fundInceptio ...

# %% [markdown]
# # Volume
# Scott

# %%
# !pip install arch

# %%
import numpy as np

start = datetime(2019, 1, 1)
end = datetime(2020, 9, 6)

novartis_vol = df_norvatis['Volume']
abbott_vol = df_abbott['Volume']
pfizer_vol = df_pfizer['Volume']
merck_vol = df_merck['Volume']
jnj_vol = df_jnj['Volume']

pharm_vol = [novartis_vol, abbott_vol, pfizer_vol, merck_vol, jnj_vol]

facebook_vol = df_facebook['Volume']
amzn_vol = df_amzn['Volume']
apple_vol = df_apple['Volume']
netflix_vol = df_netflix['Volume']
google_vol = df_google['Volume']
faang_vol = [facebook_vol, amzn_vol, apple_vol, netflix_vol, google_vol]

color = ['teal','dodgerblue','skyblue','darkturquoise','royalblue']
names = ['Facebook','Amazon','Apple','Netflix','Google']

# %%
fig, ax1 = plt.subplots(figsize=(20,20), nrows=len(faang_vol))
i = 0
for vol in faang_vol:
      ax1[i].plot(np.log(vol), color[i], lw=1)
      ax1[i].set_title(names[i])
      i+=1

# %% [markdown]
# # Stock Returns
# Jeffery

# %%
 #start end
start = datetime(2019, 1, 1)
end = datetime(2020, 9, 6)
 
 #for the returns graphs
  
df = yf.download(['^GSPC', 'AAPL', 'FB','AMZN','GOOG','NFLX','NVS','ABT','PFE','MRK','JNJ'], 
                 start=start, 
                 end=end,
                 progress=False)

df = df[['Adj Close']]
df.columns = df.columns.droplevel(0)

df['aapl_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))
df['jnj_rtn'] = np.log(df.JNJ / df.JNJ.shift(1))
df['medical_rtn'] = np.log(df.NVS / df.NVS.shift(1))*0.2 + np.log(df.ABT / df.ABT.shift(1))*0.2 + np.log(df.PFE / df.PFE.shift(1))*0.2 + np.log(df.MRK / df.MRK.shift(1))*0.2 + np.log(df.JNJ / df.JNJ.shift(1))*0.2
df['tech_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))*0.2 + np.log(df.FB / df.FB.shift(1))*0.2 + np.log(df.AMZN / df.AMZN.shift(1))*0.2 + np.log(df.GOOG / df.GOOG.shift(1))*0.2 + np.log(df.NFLX / df.NFLX.shift(1))*0.2
df['all_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))*0.1 + np.log(df.FB / df.FB.shift(1))*0.1 + np.log(df.AMZN / df.AMZN.shift(1))*0.1 + np.log(df.GOOG / df.GOOG.shift(1))*0.1 + np.log(df.NFLX / df.NFLX.shift(1))*0.1 + np.log(df.NVS / df.NVS.shift(1))*0.1 + np.log(df.ABT / df.ABT.shift(1))*0.1 + np.log(df.PFE / df.PFE.shift(1))*0.1 + np.log(df.MRK / df.MRK.shift(1))*0.1 + np.log(df.JNJ / df.JNJ.shift(1))*0.1


fig, ax = plt.subplots(1, 1, figsize=(24, 5))

df.aapl_rtn.plot(color = 'darkturquoise')
ax.set(xlabel = 'Date', 
          ylabel = 'Log returns (%)', 
          title = 'AAPL Returns time series')

fig, ax = plt.subplots(1, 1, figsize=(24, 5))
df.jnj_rtn.plot(color = 'red')
ax.set(xlabel = 'Date', 
          ylabel = 'Log returns (%)', 
          title = 'JNJ Returns time series')

#plot graphs
plt.figure(figsize=(24,10))
#plt.plot(medical_rtn, 'green',label = '5 Medical Stocks')
#plt.plot(tech_rtn, 'purple',label = 'FAANG Stocks')
#plt.plot(all_rtn, 'black',label = 'All 10 Stocks')

df.medical_rtn.plot(color = 'green')
df.tech_rtn.plot(color = 'purple')
df.all_rtn.plot(color = 'black')

plt.xlabel('Date')
plt.ylabel('Log Returns %')
plt.title('Returns time series')
plt.legend(['5 Medical Stocks', 'FAANG Stocks' ,'All 10 Stocks'])

# %% [markdown]
# # Correlation of Stocks
# (Jeffery)

# %%
#start of the correlation graph
df = yf.download(['^GSPC', 'AAPL', 'FB','AMZN','GOOG','NFLX','NVS','ABT','PFE','MRK','JNJ'], 
                 start=start, 
                 end=end,
                 progress=False)

df = df[['Adj Close']]
df.columns = df.columns.droplevel(0)
df = df.rename(columns={'^GSPC': 'sp500'})

#Apple stock example

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

fig, ax = plt.subplots(1, 2, figsize=(24, 10))

ax[0] = sns.regplot(ax = ax[0], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'darkturquoise'})
ax[0].set(title=f'S&P 500 vs. Apple ($\\rho$ = {corr_coeff:.2f})',
       ylabel='Apple log returns',
       xlabel='S&P 500 log returns')

#JNJ stock example

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.JNJ / df.JNJ.shift(1))
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

ax[1] = sns.regplot(ax = ax[1], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'red'})
ax[1].set(title=f'S&P 500 vs. JNJ ($\\rho$ = {corr_coeff:.2f})',
       ylabel='JNJ log returns',
       xlabel='S&P 500 log returns')


#5 FAANG stock example
#'AAPL', 'FB','AMZN','GOOG','NFLX'

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))*0.2 + np.log(df.FB / df.FB.shift(1))*0.2 + np.log(df.AMZN / df.AMZN.shift(1))*0.2 + np.log(df.GOOG / df.GOOG.shift(1))*0.2 + np.log(df.NFLX / df.NFLX.shift(1))*0.2
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

fig, ax = plt.subplots(1, 2, figsize=(24, 10))

ax[0] = sns.regplot(ax = ax[0], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'purple'})
ax[0].set(title=f'S&P 500 vs. FANNG Stocks ($\\rho$ = {corr_coeff:.2f})',
       ylabel='FANNG log returns',
       xlabel='S&P 500 log returns')

#NVS','ABT','PFE','MRK','JNJ' 

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.NVS / df.NVS.shift(1))*0.2 + np.log(df.ABT / df.ABT.shift(1))*0.2 + np.log(df.PFE / df.PFE.shift(1))*0.2 + np.log(df.MRK / df.MRK.shift(1))*0.2 + np.log(df.JNJ / df.JNJ.shift(1))*0.2
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

ax[1] = sns.regplot(ax = ax[1], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'green'}, scatter_kws={"color": "orange"})
ax[1].set(title=f'S&P 500 vs. 5 Pharma Stocks ($\\rho$ = {corr_coeff:.2f})',
       ylabel='5 Pharma log returns',
       xlabel='S&P 500 log returns')



#Combined Example from the 2nd row graphs

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))*0.2 + np.log(df.FB / df.FB.shift(1))*0.2 + np.log(df.AMZN / df.AMZN.shift(1))*0.2 + np.log(df.GOOG / df.GOOG.shift(1))*0.2 + np.log(df.NFLX / df.NFLX.shift(1))*0.2
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

fig, ax = plt.subplots(1, 2, figsize=(24, 10))

ax[0] = sns.regplot(ax = ax[0], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'purple'})
ax[0].set(title=f'S&P 500 vs. Tech Stocks',
       ylabel='Stock log returns',
       xlabel='S&P 500 log returns')

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.NVS / df.NVS.shift(1))*0.2 + np.log(df.ABT / df.ABT.shift(1))*0.2 + np.log(df.PFE / df.PFE.shift(1))*0.2 + np.log(df.MRK / df.MRK.shift(1))*0.2 + np.log(df.JNJ / df.JNJ.shift(1))*0.2
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

ax[0] = sns.regplot(ax = ax[0], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'green'}, scatter_kws={"color": "orange"})
ax[0].set(title=f'S&P 500 vs. Stocks',
       ylabel='Stock log returns',
       xlabel='S&P 500 log returns')

#All stocks combined

df['index_rtn'] = np.log(df.sp500 / df.sp500.shift(1))
df['share_rtn'] = np.log(df.AAPL / df.AAPL.shift(1))*0.1 + np.log(df.FB / df.FB.shift(1))*0.1 + np.log(df.AMZN / df.AMZN.shift(1))*0.1 + np.log(df.GOOG / df.GOOG.shift(1))*0.1 + np.log(df.NFLX / df.NFLX.shift(1))*0.1 + np.log(df.NVS / df.NVS.shift(1))*0.1 + np.log(df.ABT / df.ABT.shift(1))*0.1 + np.log(df.PFE / df.PFE.shift(1))*0.1 + np.log(df.MRK / df.MRK.shift(1))*0.1 + np.log(df.JNJ / df.JNJ.shift(1))*0.1
df.dropna(how='any', axis=0, inplace=True)

corr_coeff = df.index_rtn.corr(df.share_rtn)

ax[1] = sns.regplot(ax = ax[1], x='index_rtn', y='share_rtn', data=df, 
                 line_kws={'color': 'black'}, scatter_kws={"color": "red"})
ax[1].set(title=f'S&P 500 vs. All 10 Stocks ($\\rho$ = {corr_coeff:.2f})',
       ylabel='All 10 Stocks log returns',
       xlabel='S&P 500 log returns')
# Out:
# [Text(0, 0.5, 'All 10 Stocks log returns'),
#  Text(0.5, 0, 'S&P 500 log returns'),
#  Text(0.5, 1.0, 'S&P 500 vs. All 10 Stocks ($\\rho$ = 0.91)')]

# %% [markdown]
# # SAMPLE

# %%
fb = yf.download('FB', start=start, end=end, progress=False)
amazon = yf.download('AMZN', start=start, end=end, progress=False)
google = yf.download('GOOG', start=start, end=end, progress=False)

# %%
fb_close = fb['Adj Close']
amazon_close = amazon['Adj Close']
google_close = google['Adj Close']

# %%
fig, ax1 = plt.subplots(figsize=(10,4))
ax2 = ax1.twinx()   # Same x axis
ax3 = ax1.twinx()

ax1.plot(fb_close, 'b', lw=1, label='Facebook')
ax1.set_xlabel('Time')

ax2.plot(amazon_close, 'r', lw=1, label='Amazon')

ax3.plot(google_close, 'g', lw=1, label='Google')

line_labels = ['Facebook','Amazon','Google']
fig.legend([ax1, ax2, ax3],        # The line objects
           labels = line_labels,   # The labels for each line
           loc="upper left",       # Position of legend
           borderaxespad=0.1,      # Small spacing around legend box
           title=''                # Title for the legend
           )
plt.show()
